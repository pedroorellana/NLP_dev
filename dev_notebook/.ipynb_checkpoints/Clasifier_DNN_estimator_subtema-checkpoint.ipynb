# %%
# Utils
import tensorflow as tf
import pandas as pd
import matplotlib.pyplot as plt

import numpy as np
import time
import pickle
import re, sys, unidecode

from sklearn.metrics import accuracy_score
from IPython.display import display, Markdown, Latex

import shutil
import os
import scipy

import scikitplot as skplt

from tensorflow.contrib.learn import DNNClassifier
# Out:
# /root/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %% [markdown]
# # Parameters

# %%
root_path = "../"
path_model = root_path + 'models/seccion'
features_path = root_path + 'data/features/data_tfid_hash28_n1000_SVD2.p'

delete_old_model = True
if delete_old_model:
    try:
        os.system("rm -rf "+path_model)
        os.system("mkdir "+path_model)
    except:
        print("error")

# %% [markdown]
# # Load Data

# %%
X, y1, y2, y3 = pickle.load( open( features_path, "rb" ) )

# %%
y1.values
# Out:
# array(['deportes', 'pais', 'pais', ..., 'cultura', 'pais', 'mundo'],
#       dtype=object)

# %% [markdown]
# # pre procesing
#
# Cleaning data, select clases

# %%
y2 = np.array(y2)
y_2 = list(map(lambda x: unidecode.unidecode(x) if x!=None else None, y2))
y_2 = np.array(y_2)


y1 = y1.values

# %% [markdown]
# # Feature Extraccion
#
# ### Data representation
#
# TFID calculation

# %% [markdown]
# ### filter clases

# %%
labels = list(set(y1))
labels
# Out:
# ['sociedad',
#  'mundo',
#  'deportes',
#  'economia',
#  'tecnologia',
#  'entretencion',
#  'cultura',
#  'pais']

# %%
def filterClases(X,y,umbral):
    labels = list(set(y))
    sizes = [ [label,y[y== label].shape[0]] for label in labels ]
    filter_sizes = list(filter(lambda x:x[1]>umbral ,sizes ))
    names_clases = set( map(lambda x:x[0], filter_sizes ) )
    index = list(map(lambda x: {x}.issubset(names_clases), y ))
    y = y[index]
    X = X[np.nonzero(index)]
    return X,y

# %%
y_temas = {}
X_temas = {}
labels_temas = {}
labels_temas_before = {}
umbral_ejemplos = 100

for key in labels:
    index = y1 == key
    y_22 = y_2[index]
    X2 = X[np.nonzero(index)]

    index = y_22 != None
    y_22 = y_22[index]
    X2 = X2[np.nonzero(index)]
    X_temas[key],y_temas[key] = filterClases(X2,y_22,umbral_ejemplos)
    
    
    labels_temas_before = list(set(y_22))
    labels_temas[key] = list(set(y_temas[key]))
    
    print("\n"+key + " ,total : " + str(len(labels_temas[key])) \
          +" ,deleted : "+ str( len(labels_temas_before) - len(labels_temas[key] )) )
    print(labels_temas[key])
# Out:
# sociedad ,total : 17 ,deleted : 12
# ['pedofilia', 'sexualidad', 'celebraciones', 'medioambiente', 'religion', 'mujer', 'desarrollo humano', 'ciencias sociales', 'homosexualidad', 'historia', 'salud', 'ciencia', 'sucesos', 'fauna', 'astronomia', 'medios', 'premios nobel']
#
# mundo ,total : 38 ,deleted : 8
# ['al qaeda', 'haiti', 'vaticano', 'ecuador', 'venezuela', 'peru', 'accidentes aereos', 'alemania', 'mexico', 'rusia', 'america latina', 'irak', 'europa', 'organismos internacionales', 'china', 'francia', 'africa', 'bolivia', 'espana', 'asia', 'pacifico sur', 'iran', 'peninsula de corea', 'afganistan', 'sudafrica', 'eeuu', 'japon', 'reino unido', 'colombia', 'brasil', 'uruguay', 'desastres naturales', 'india', 'medio oriente', 'italia', 'cuba', 'argentina', 'paraguay']
#
# deportes ,total : 33 ,deleted : 11
# ['baloncesto', 'brasil ', 'polideportivo', 'velerismo', 'hockey patin', 'voleibol', 'balonmano', 'olimpismo', 'gobierno', 'natacion', 'torneo de clausura', 'copa america', 'boxeo', 'copa libertadores', 'triatlon', 'paralimpicos', 'al aire libre', 'automovilismo', 'londres ', 'torneo de apertura', 'eurocopa', 'mundiales de futbol', 'gimnasia', 'tenis de mesa', 'ciclismo', 'copa davis', 'rally', 'golf', 'tenis', 'atletismo', 'futbol', 'motociclismo', 'rugby']
#
# economia ,total : 16 ,deleted : 2
# ['impuestos', 'sectores productivos', 'crecimiento', 'competitividad', 'crisis financiera', 'bolsas', 'sistema previsional', 'servicios financieros', 'organismos internacionales', 'sueldo minimo', 'divisas', 'materias primas', 'retail', 'banco central', 'empresas', 'presupuesto']
#
# tecnologia ,total : 4 ,deleted : 3
# ['industria', 'inventos', 'internet', 'redes sociales']
#
# entretencion ,total : 14 ,deleted : 4
# ['festival de vina', 'musica', 'comic', 'tendencias', 'panoramas', 'television', 'personajes', 'listas', 'cine', 'espectaculos', 'festivales', 'humor', 'sucesos', 'radio']
#
# cultura ,total : 4 ,deleted : 8
# ['cultura popular', 'arte', 'teatro', 'literatura']
#
# pais ,total : 52 ,deleted : 15
# ['region de valparaiso', 'seguridad ciudadana', 'vivienda', 'pueblos originarios', 'salud', 'region de la araucania', 'michelle bachelet', 'relaciones exteriores', 'region de los lagos', 'energia', 'ddhh', 'sebastian pinera', 'region de antofagasta', 'iglesia catolica', 'organismos del estado', 'trabajo', 'empresas del estado', 'mujer', 'gobierno', 'region de los rios', 'augusto pinochet', 'isla de pascua', 'ciudades', 'servicios publicos', 'manifestaciones', 'poblacion', 'tiempo', 'region de aysen', 'policial', 'infancia', 'medioambiente', 'region de magallanes', 'presidente pinera', 'presidenta bachelet', 'educacion', 'obras publicas', 'ffaa y de orden', 'region del biobio', 'region del maule', 'judicial', 'region de arica', 'festivos', 'servicios', 'desastres naturales', 'region de atacama', 'sismos', 'politicas sociales', 'transportes', 'turismo', 'region de coquimbo', 'politica', 'consumidores']

# %% [markdown]
# ### Output

# %%
np.random.seed(42)
train_fraction = 0.8

X_train = {}
y_train = {}
X_test = {}
y_test = {}
train_indices = {}
test_indices = {}

for key in labels:
    train_indices[key] = np.random.choice(X_temas[key].shape[0], round(train_fraction*X_temas[key].shape[0]), replace=False)
    test_indices[key] = np.array(list(set(range(X_temas[key].shape[0])) - set(train_indices)))

    X_train[key] = X_temas[key][train_indices[key]]
    y_train[key] = y_temas[key][train_indices[key]]
    X_test[key] = X_temas[key][test_indices[key]]
    y_test[key] = y_temas[key][test_indices[key]]

# %%
weights_train = {}
weights_test = {}

np.random.seed(42)

for key in labels:
    labelsTmp = list(set(y_train[key]))
    nClasses = len(labelsTmp)

    sizes = {label: y_train[key][y_train[key] == label].shape[0] for label in labelsTmp}
    weights = np.asarray([len(y_train[key])/(sizes[label]*nClasses) for label in y_temas[key]])

    weights = weights[:,np.newaxis]
    weights_train[key] = weights[train_indices[key]]
    weights_test[key] = weights[test_indices[key]]

# %% [markdown]
# # Model
#
# ### DNN graph generation

# %%
epochs = 14000

if isinstance(X_train, scipy.sparse.csr.csr_matrix):
    X_train = X_train.todense()
    X_test = X_test.todense()

# Define the test inputs
def get_train_inputs(key):    
    dataset = tf.estimator.inputs.numpy_input_fn({'x': X_train[key],'class_weights': weights_train[key]},
                                                  y_train[key][:,np.newaxis],
                                                  shuffle=True,
                                                  batch_size=50,
                                                  num_epochs=epochs)
    return dataset

def get_test_inputs(key):   
    dataset = tf.estimator.inputs.numpy_input_fn({'x': X_test[key],'class_weights': weights_test[key]},
                                                  y_test[key][:,np.newaxis],
                                                  shuffle=False)
    return dataset

# %% [markdown]
# ### functions graph tensorflow

# %%
tf.set_random_seed(42)
feature_columns = [tf.contrib.layers.real_valued_column('x', dimension=1000)]

classifier = {}
path_all_models  = {}
for key in labels:
    path_all_models[key] = path_model+"/"+str(key)
    classifier[key] = DNNClassifier(                                
                               n_classes=len(labels_temas[key]), label_keys=labels_temas[key], feature_columns=feature_columns,
                               hidden_units=[2000],
                               dropout=0.5,
                               weight_column_name='class_weights',
                               model_dir = path_model+"/"+str(key),
                               config = tf.contrib.learn.RunConfig(save_checkpoints_steps = 500,
                               save_checkpoints_secs = None)                           
                              )
# Out:
# WARNING:tensorflow:From <ipython-input-12-257465d11a78>:17: RunConfig.__init__ (from tensorflow.contrib.learn.python.learn.estimators.run_config) is deprecated and will be removed in a future version.
# Instructions for updating:
# When switching to tf.estimator.Estimator, use tf.estimator.RunConfig instead.
# WARNING:tensorflow:From /root/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/estimators/dnn.py:378: multi_class_head (from tensorflow.contrib.learn.python.learn.estimators.head) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please switch to tf.contrib.estimator.*_head.
# WARNING:tensorflow:From /root/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/estimators/estimator.py:1179: BaseEstimator.__init__ (from tensorflow.contrib.learn.python.learn.estimators.estimator) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please replace uses of any Estimator from tf.contrib.learn with an Estimator from tf.estimator.*
# INFO:tensorflow:Using config: {'_task_type': None, '_task_id': 0, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f44aae704a8>, '_master': '', '_num_ps_replicas': 0, '_num_worker_replicas': 0, '_environment': 'local', '_is_chief': True, '_evaluation_master': '', '_train_distribute': None, '_device_fn': None, '_tf_config': gpu_options {
#   per_process_gpu_memory_fraction: 1.0
# }
# , '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_secs': None, '_log_step_count_steps': 100, '_session_config': None, '_save_checkpoints_steps': 500, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_model_dir': '../models/seccion/sociedad'}
# INFO:tensorflow:Using config: {'_task_type': None, '_task_id': 0, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f44aae70550>, '_master': '', '_num_ps_replicas': 0, '_num_worker_replicas': 0, '_environment': 'local', '_is_chief': True, '_evaluation_master': '', '_train_distribute': None, '_device_fn': None, '_tf_config': gpu_options {
#   per_process_gpu_memory_fraction: 1.0
# }
# , '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_secs': None, '_log_step_count_steps': 100, '_session_config': None, '_save_checkpoints_steps': 500, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_model_dir': '../models/seccion/mundo'}
# INFO:tensorflow:Using config: {'_task_type': None, '_task_id': 0, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f44aae70390>, '_master': '', '_num_ps_replicas': 0, '_num_worker_replicas': 0, '_environment': 'local', '_is_chief': True, '_evaluation_master': '', '_train_distribute': None, '_device_fn': None, '_tf_config': gpu_options {
#   per_process_gpu_memory_fraction: 1.0
# }
# , '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_secs': None, '_log_step_count_steps': 100, '_session_config': None, '_save_checkpoints_steps': 500, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_model_dir': '../models/seccion/deportes'}
# INFO:tensorflow:Using config: {'_task_type': None, '_task_id': 0, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f44aae70358>, '_master': '', '_num_ps_replicas': 0, '_num_worker_replicas': 0, '_environment': 'local', '_is_chief': True, '_evaluation_master': '', '_train_distribute': None, '_device_fn': None, '_tf_config': gpu_options {
#   per_process_gpu_memory_fraction: 1.0
# }
# , '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_secs': None, '_log_step_count_steps': 100, '_session_config': None, '_save_checkpoints_steps': 500, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_model_dir': '../models/seccion/economia'}
# INFO:tensorflow:Using config: {'_task_type': None, '_task_id': 0, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f44aae708d0>, '_master': '', '_num_ps_replicas': 0, '_num_worker_replicas': 0, '_environment': 'local', '_is_chief': True, '_evaluation_master': '', '_train_distribute': None, '_device_fn': None, '_tf_config': gpu_options {
#   per_process_gpu_memory_fraction: 1.0
# }
# , '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_secs': None, '_log_step_count_steps': 100, '_session_config': None, '_save_checkpoints_steps': 500, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_model_dir': '../models/seccion/tecnologia'}
# INFO:tensorflow:Using config: {'_task_type': None, '_task_id': 0, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f44aae70518>, '_master': '', '_num_ps_replicas': 0, '_num_worker_replicas': 0, '_environment': 'local', '_is_chief': True, '_evaluation_master': '', '_train_distribute': None, '_device_fn': None, '_tf_config': gpu_options {
#   per_process_gpu_memory_fraction: 1.0
# }
# , '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_secs': None, '_log_step_count_steps': 100, '_session_config': None, '_save_checkpoints_steps': 500, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_model_dir': '../models/seccion/entretencion'}
# INFO:tensorflow:Using config: {'_task_type': None, '_task_id': 0, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f44aae70908>, '_master': '', '_num_ps_replicas': 0, '_num_worker_replicas': 0, '_environment': 'local', '_is_chief': True, '_evaluation_master': '', '_train_distribute': None, '_device_fn': None, '_tf_config': gpu_options {
#   per_process_gpu_memory_fraction: 1.0
# }
# , '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_secs': None, '_log_step_count_steps': 100, '_session_config': None, '_save_checkpoints_steps': 500, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_model_dir': '../models/seccion/cultura'}
# INFO:tensorflow:Using config: {'_task_type': None, '_task_id': 0, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f44aae709e8>, '_master': '', '_num_ps_replicas': 0, '_num_worker_replicas': 0, '_environment': 'local', '_is_chief': True, '_evaluation_master': '', '_train_distribute': None, '_device_fn': None, '_tf_config': gpu_options {
#   per_process_gpu_memory_fraction: 1.0
# }
# , '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_secs': None, '_log_step_count_steps': 100, '_session_config': None, '_save_checkpoints_steps': 500, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_model_dir': '../models/seccion/pais'}

# %% [markdown]
# # Training

# %%
#validation_monitor = {}

print("start")
start = time.time()

for key in labels:
    
    validation_monitor = tf.contrib.learn.monitors.ValidationMonitor(
        #input_fn= get_train_inputs(),
        input_fn= get_test_inputs(key),    
        every_n_steps=500,
        #early_stopping_metric="accuracy",#loss
        early_stopping_metric="loss",
        early_stopping_metric_minimize=True,
        early_stopping_rounds=2000)

    

    classifier[key].fit(input_fn=get_train_inputs(key), monitors=[validation_monitor], steps=epochs, max_steps=None)
    print("###################### "+key+" ######################")
    
end = time.time()
#print(key)
print("Training time :" + str(end - start) )
# Out:
# start
# WARNING:tensorflow:From /root/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:279: BaseMonitor.__init__ (from tensorflow.contrib.learn.python.learn.monitors) is deprecated and will be removed after 2016-12-05.
# Instructions for updating:
# Monitors are deprecated. Please use tf.train.SessionRunHook.
# WARNING:tensorflow:From /root/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:678: ModelFnOps.__new__ (from tensorflow.contrib.learn.python.learn.estimators.model_fn) is deprecated and will be removed in a future version.
# Instructions for updating:
# When switching to tf.estimator.Estimator, use tf.estimator.EstimatorSpec. You can use the `estimator_spec` method to create an equivalent one.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into ../models/seccion/sociedad/model.ckpt.
# INFO:tensorflow:loss = 2.4225492, step = 1
# INFO:tensorflow:global_step/sec: 104.741
# INFO:tensorflow:loss = 2.8551633, step = 101 (0.956 sec)
# INFO:tensorflow:global_step/sec: 133.128
# INFO:tensorflow:loss = 2.7938921, step = 201 (0.751 sec)
# INFO:tensorflow:global_step/sec: 130.613
# INFO:tensorflow:loss = 2.230655, step = 301 (0.766 sec)
# INFO:tensorflow:global_step/sec: 123.998
# INFO:tensorflow:loss = 2.0149322, step = 401 (0.806 sec)
# INFO:tensorflow:Saving checkpoints for 500 into ../models/seccion/sociedad/model.ckpt.
# INFO:tensorflow:Starting evaluation at 2018-10-12-01:05:14
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../models/seccion/sociedad/model.ckpt-500
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-10-12-01:05:14
# INFO:tensorflow:Saving dict for global step 500: accuracy = 0.52033687, global_step = 500, loss = 2.4576902
# INFO:tensorflow:Validation (step 500): loss = 2.4576902, accuracy = 0.52033687, global_step = 500
# INFO:tensorflow:global_step/sec: 59.2059
# INFO:tensorflow:loss = 2.1967745, step = 501 (1.689 sec)
# INFO:tensorflow:global_step/sec: 129.992
# INFO:tensorflow:loss = 2.276846, step = 601 (0.770 sec)
# INFO:tensorflow:global_step/sec: 127.818
# INFO:tensorflow:loss = 2.3020499, step = 701 (0.782 sec)
# INFO:tensorflow:global_step/sec: 130
# INFO:tensorflow:loss = 1.7203515, step = 801 (0.769 sec)
# INFO:tensorflow:global_step/sec: 125.402
# INFO:tensorflow:loss = 1.7186829, step = 901 (0.798 sec)
# INFO:tensorflow:Saving checkpoints for 1000 into ../models/seccion/sociedad/model.ckpt.
# INFO:tensorflow:global_step/sec: 105.8
# INFO:tensorflow:loss = 1.2258804, step = 1001 (0.945 sec)
# INFO:tensorflow:global_step/sec: 115.828
# INFO:tensorflow:loss = 1.1463338, step = 1101 (0.863 sec)
# INFO:tensorflow:global_step/sec: 116.787
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-10-12-01:24:10
# INFO:tensorflow:Saving dict for global step 13500: accuracy = 0.7662417, global_step = 13500, loss = 0.87835425
# INFO:tensorflow:Validation (step 13500): loss = 0.87835425, accuracy = 0.7662417, global_step = 13500
# INFO:tensorflow:global_step/sec: 24.4232
# INFO:tensorflow:loss = 0.7527032, step = 13501 (4.094 sec)
# INFO:tensorflow:global_step/sec: 121.955
# INFO:tensorflow:loss = 0.72914076, step = 13601 (0.820 sec)
# INFO:tensorflow:global_step/sec: 122.919
# INFO:tensorflow:loss = 0.879928, step = 13701 (0.814 sec)
# INFO:tensorflow:global_step/sec: 117.16
# INFO:tensorflow:loss = 1.1333077, step = 13801 (0.853 sec)
# INFO:tensorflow:global_step/sec: 120.963
# INFO:tensorflow:loss = 0.839476, step = 13901 (0.827 sec)
# INFO:tensorflow:Saving checkpoints for 14000 into ../models/seccion/pais/model.ckpt.
# INFO:tensorflow:Starting evaluation at 2018-10-12-01:24:14
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../models/seccion/pais/model.ckpt-14000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-10-12-01:24:17
# INFO:tensorflow:Saving dict for global step 14000: accuracy = 0.7683117, global_step = 14000, loss = 0.8637998
# INFO:tensorflow:Validation (step 14000): loss = 0.8637998, accuracy = 0.7683117, global_step = 14000
# INFO:tensorflow:Loss for final step: 0.88776016.
# ###################### pais ######################
# Training time :1149.0881145000458

# %% [markdown]
# # Evaluation performance

# %%
pred_test = {}
y_test_hat = {}
y_test_hat = {}
acc = {}

for key in labels:

    def input_fn_evaluate():
        dataset = {'x': tf.constant(X_test[key])}    
        return dataset

    pred_test[key] = classifier[key].predict_classes(input_fn=input_fn_evaluate)
    y_test_hat[key] = np.asarray([x.decode('UTF-8') for x in list(pred_test[key])])
    y_test_hat[key] = y_test_hat[key].astype(str)
    acc[key] = accuracy_score(y_true=y_test[key], y_pred=y_test_hat[key])
# Out:
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../models/seccion/sociedad/model.ckpt-14000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../models/seccion/mundo/model.ckpt-14000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../models/seccion/deportes/model.ckpt-14000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../models/seccion/economia/model.ckpt-14000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../models/seccion/tecnologia/model.ckpt-8500
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../models/seccion/entretencion/model.ckpt-14000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../models/seccion/cultura/model.ckpt-10000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../models/seccion/pais/model.ckpt-14000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.

# %%
for key in labels:
    display(Markdown('## ' + key))
    display(Markdown('## Accuracy in test: {} '.format(acc[key]*100)))    
    skplt.metrics.plot_confusion_matrix(y_test[key], y_test_hat[key],normalize=True,figsize=(20,20))
    plt.xticks(rotation=45)
    plt.show()
    #print('Accuracy in test: {}'.format(acc))
# Out:
# ## sociedad
# ## Accuracy in test: 89.4650011784115
# ## mundo
# ## Accuracy in test: 85.85249042145594
# ## deportes
# ## Accuracy in test: 75.93031212169062
# ## economia
# ## Accuracy in test: 95.1256793478261
# ## tecnologia
# ## Accuracy in test: 88.83774453394706
# ## entretencion
# ## Accuracy in test: 80.51175041904696
# ## cultura
# ## Accuracy in test: 98.34150018846589
# ## pais
# ## Accuracy in test: 64.9367805246273

# %% [markdown]
# ###  Save info model

# %%
pickle.dump( (path_all_models,labels_temas), open( path_model + "/info_model.p", "wb" ) )
