# %%
# Utils
import tensorflow as tf
import pandas as pd
import matplotlib.pyplot as plt

import numpy as np
import time
#import _pickle as pickle
import pickle
import re, sys, unidecode
#import unidecode

from sklearn.metrics import accuracy_score
from IPython.display import display, Markdown, Latex

import shutil
import os

# Representation
import nltk
from nltk.corpus import stopwords
import scikitplot as skplt

from tensorflow.contrib.learn import DNNClassifier

# %%
#plt.style.use('fivethirtyeight')

nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to /home/pedro/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /home/pedro/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %% [markdown]
# # Parameters

# %%
root_path = "../"
path_model = root_path + 'models/test'
features_path = root_path + 'data/features/data_tfid_hash28_n1000.p'

delete_old_model = True
if delete_old_model:
    try:
        os.system("rm -rf "+path_model)
        os.system("mkdir "+path_model)
    except:
        print("error")

# %% [markdown]
# # Load Data

# %%
X, y1, y2, y3 = pickle.load( open( features_path, "rb" ) )

# %%
y1.values
# Out:
# array(['deportes', 'pais', 'pais', ..., 'cultura', 'pais', 'mundo'],
#       dtype=object)

# %% [markdown]
# # pre procesing
#
# Cleaning data, select clases

# %%
newClases = np.array(y2)
y_newClases = list(map(lambda x: unidecode.unidecode(x) if x!=None else None, newClases))
y_newClases = np.array(y_newClases)


y = y1.values

# %% [markdown]
# # Feature Extraccion
#
# ### Data representation
#
# TFID calculation

# %% [markdown]
# ### filter clases

# %%
labels = list(set(y))
labels
# Out:
# ['cultura',
#  'mundo',
#  'economia',
#  'deportes',
#  'entretencion',
#  'sociedad',
#  'pais',
#  'tecnologia']

# %%
def filterClases(X,y,umbral):
    labels = list(set(y))
    sizes = [ [label,y[y== label].shape[0]] for label in labels ]
    filter_sizes = list(filter(lambda x:x[1]>umbral ,sizes ))
    names_clases = set( map(lambda x:x[0], filter_sizes ) )
    index = list(map(lambda x: {x}.issubset(names_clases), y ))
    y = y[index]
    X = X[np.nonzero(index)]
    return X,y

# %%
y_temas = {}
X_temas = {}
labels_temas = {}
umbral_ejemplos = 100

for key in labels:
    index = y == key
    y_newClases2 = y_newClases[index]
    X2 = X[np.nonzero(index)]

    index = y_newClases2 != None
    y_newClases2 = y_newClases2[index]
    X2 = X2[np.nonzero(index)]
    X_temas[key],y_temas[key] = filterClases(X2,y_newClases2,umbral_ejemplos)
    
    labels_temas[key] = list(set(y_temas[key]))
    
    print("\n"+key)
    print(labels_temas[key])
# Out:
# cultura
# ['literatura', 'arte', 'cultura popular', 'teatro']
#
# mundo
# ['argentina', 'brasil', 'china', 'vaticano', 'cuba', 'pacifico sur', 'europa', 'eeuu', 'irak', 'uruguay', 'paraguay', 'japon', 'francia', 'asia', 'africa', 'alemania', 'desastres naturales', 'iran', 'india', 'afganistan', 'accidentes aereos', 'organismos internacionales', 'haiti', 'colombia', 'medio oriente', 'espana', 'peru', 'venezuela', 'rusia', 'mexico', 'america latina', 'bolivia', 'sudafrica', 'ecuador', 'peninsula de corea', 'italia', 'al qaeda', 'reino unido']
#
# economia
# ['divisas', 'sistema previsional', 'bolsas', 'retail', 'sectores productivos', 'crecimiento', 'empresas', 'crisis financiera', 'presupuesto', 'banco central', 'competitividad', 'impuestos', 'sueldo minimo', 'servicios financieros', 'materias primas', 'organismos internacionales']
#
# deportes
# ['hockey patin', 'atletismo', 'copa libertadores', 'automovilismo', 'al aire libre', 'natacion', 'ciclismo', 'torneo de clausura', 'balonmano', 'boxeo', 'velerismo', 'rally', 'motociclismo', 'triatlon', 'gobierno', 'londres ', 'polideportivo', 'brasil ', 'olimpismo', 'golf', 'paralimpicos', 'torneo de apertura', 'voleibol', 'tenis de mesa', 'tenis', 'futbol', 'copa davis', 'eurocopa', 'mundiales de futbol', 'baloncesto', 'rugby', 'gimnasia', 'copa america']
#
# entretencion
# ['television', 'festivales', 'sucesos', 'comic', 'festival de vina', 'musica', 'espectaculos', 'panoramas', 'radio', 'humor', 'listas', 'personajes', 'cine', 'tendencias']
#
# sociedad
# ['sucesos', 'desarrollo humano', 'sexualidad', 'medios', 'ciencias sociales', 'religion', 'ciencia', 'premios nobel', 'homosexualidad', 'medioambiente', 'fauna', 'mujer', 'astronomia', 'celebraciones', 'salud', 'pedofilia', 'historia']
#
# pais
# ['manifestaciones', 'region de aysen', 'servicios', 'sebastian pinera', 'region de coquimbo', 'region de antofagasta', 'medioambiente', 'empresas del estado', 'relaciones exteriores', 'consumidores', 'region de los lagos', 'pueblos originarios', 'educacion', 'transportes', 'gobierno', 'festivos', 'politica', 'region de magallanes', 'region de valparaiso', 'desastres naturales', 'salud', 'servicios publicos', 'isla de pascua', 'vivienda', 'michelle bachelet', 'presidente pinera', 'organismos del estado', 'energia', 'iglesia catolica', 'judicial', 'region de la araucania', 'seguridad ciudadana', 'ffaa y de orden', 'turismo', 'infancia', 'policial', 'poblacion', 'tiempo', 'obras publicas', 'region del biobio', 'region del maule', 'ddhh', 'presidenta bachelet', 'politicas sociales', 'ciudades', 'sismos', 'mujer', 'region de atacama', 'region de los rios', 'region de arica', 'augusto pinochet', 'trabajo']
#
# tecnologia
# ['industria', 'internet', 'redes sociales', 'inventos']

# %% [markdown]
# ### Output

# %%
np.random.seed(42)
train_fraction = 0.8

X_train = {}
y_train = {}
X_test = {}
y_test = {}
train_indices = {}
test_indices = {}

for key in labels:
    train_indices[key] = np.random.choice(X_temas[key].shape[0], round(train_fraction*X_temas[key].shape[0]), replace=False)
    test_indices[key] = np.array(list(set(range(X_temas[key].shape[0])) - set(train_indices)))

    X_train[key] = X_temas[key][train_indices[key]]
    y_train[key] = y_temas[key][train_indices[key]]
    X_test[key] = X_temas[key][test_indices[key]]
    y_test[key] = y_temas[key][test_indices[key]]

# %%
weights_train = {}
weights_test = {}

np.random.seed(42)

for key in labels:
    labelsTmp = list(set(y_train[key]))
    nClasses = len(labelsTmp)

    sizes = {label: y_train[key][y_train[key] == label].shape[0] for label in labelsTmp}
    weights = np.asarray([len(y_train[key])/(sizes[label]*nClasses) for label in y_temas[key]])

    weights = weights[:,np.newaxis]
    weights_train[key] = weights[train_indices[key]]
    weights_test[key] = weights[test_indices[key]]

# %% [markdown]
# # Model
#
# ### DNN graph generation

# %%
epochs = 14000

# Define the test inputs
def get_train_inputs(key):    
    dataset = tf.estimator.inputs.numpy_input_fn({'x': X_train[key].todense(),'class_weights': weights_train[key]},
                                                  y_train[key][:,np.newaxis],
                                                  shuffle=True,
                                                  batch_size=500,
                                                  num_epochs=epochs)
    return dataset

def get_test_inputs(key):   
    dataset = tf.estimator.inputs.numpy_input_fn({'x': X_test[key].todense(),'class_weights': weights_test[key]},
                                                  y_test[key][:,np.newaxis],
                                                  shuffle=False)
    return dataset

# %% [markdown]
# ### functions graph tensorflow

# %%
tf.set_random_seed(42)
feature_columns = [tf.contrib.layers.real_valued_column('x', dimension=1000)]

classifier = {}
for key in labels:
    classifier[key] = DNNClassifier(                                
                               n_classes=len(labels_temas[key]), label_keys=labels_temas[key], feature_columns=feature_columns,
                               hidden_units=[2000],
                               dropout=0.5,
                               weight_column_name='class_weights',
                               model_dir = path_model+"/"str(key),
                               config = tf.contrib.learn.RunConfig(save_checkpoints_steps = 500,
                               save_checkpoints_secs = None)                           
                              )
# Out:
# WARNING:tensorflow:From <ipython-input-13-31d4798bccee>:15: RunConfig.__init__ (from tensorflow.contrib.learn.python.learn.estimators.run_config) is deprecated and will be removed in a future version.
# Instructions for updating:
# When switching to tf.estimator.Estimator, use tf.estimator.RunConfig instead.
# WARNING:tensorflow:From /home/pedro/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/estimators/dnn.py:378: multi_class_head (from tensorflow.contrib.learn.python.learn.estimators.head) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please switch to tf.contrib.estimator.*_head.
# WARNING:tensorflow:From /home/pedro/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/estimators/estimator.py:1179: BaseEstimator.__init__ (from tensorflow.contrib.learn.python.learn.estimators.estimator) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please replace uses of any Estimator from tf.contrib.learn with an Estimator from tf.estimator.*
# INFO:tensorflow:Using config: {'_task_type': None, '_task_id': 0, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7fc6963983c8>, '_master': '', '_num_ps_replicas': 0, '_num_worker_replicas': 0, '_environment': 'local', '_is_chief': True, '_evaluation_master': '', '_train_distribute': None, '_tf_config': gpu_options {
#   per_process_gpu_memory_fraction: 1.0
# }
# , '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_secs': None, '_log_step_count_steps': 100, '_session_config': None, '_save_checkpoints_steps': 500, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_model_dir': '../models/testcultura'}
# INFO:tensorflow:Using config: {'_task_type': None, '_task_id': 0, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7fc696398b00>, '_master': '', '_num_ps_replicas': 0, '_num_worker_replicas': 0, '_environment': 'local', '_is_chief': True, '_evaluation_master': '', '_train_distribute': None, '_tf_config': gpu_options {
#   per_process_gpu_memory_fraction: 1.0
# }
# , '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_secs': None, '_log_step_count_steps': 100, '_session_config': None, '_save_checkpoints_steps': 500, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_model_dir': '../models/testmundo'}
# INFO:tensorflow:Using config: {'_task_type': None, '_task_id': 0, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7fc696398780>, '_master': '', '_num_ps_replicas': 0, '_num_worker_replicas': 0, '_environment': 'local', '_is_chief': True, '_evaluation_master': '', '_train_distribute': None, '_tf_config': gpu_options {
#   per_process_gpu_memory_fraction: 1.0
# }
# , '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_secs': None, '_log_step_count_steps': 100, '_session_config': None, '_save_checkpoints_steps': 500, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_model_dir': '../models/testeconomia'}
# INFO:tensorflow:Using config: {'_task_type': None, '_task_id': 0, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7fc6963ace10>, '_master': '', '_num_ps_replicas': 0, '_num_worker_replicas': 0, '_environment': 'local', '_is_chief': True, '_evaluation_master': '', '_train_distribute': None, '_tf_config': gpu_options {
#   per_process_gpu_memory_fraction: 1.0
# }
# , '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_secs': None, '_log_step_count_steps': 100, '_session_config': None, '_save_checkpoints_steps': 500, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_model_dir': '../models/testdeportes'}
# INFO:tensorflow:Using config: {'_task_type': None, '_task_id': 0, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7fc6963ac9e8>, '_master': '', '_num_ps_replicas': 0, '_num_worker_replicas': 0, '_environment': 'local', '_is_chief': True, '_evaluation_master': '', '_train_distribute': None, '_tf_config': gpu_options {
#   per_process_gpu_memory_fraction: 1.0
# }
# , '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_secs': None, '_log_step_count_steps': 100, '_session_config': None, '_save_checkpoints_steps': 500, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_model_dir': '../models/testentretencion'}
# INFO:tensorflow:Using config: {'_task_type': None, '_task_id': 0, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7fc6963accf8>, '_master': '', '_num_ps_replicas': 0, '_num_worker_replicas': 0, '_environment': 'local', '_is_chief': True, '_evaluation_master': '', '_train_distribute': None, '_tf_config': gpu_options {
#   per_process_gpu_memory_fraction: 1.0
# }
# , '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_secs': None, '_log_step_count_steps': 100, '_session_config': None, '_save_checkpoints_steps': 500, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_model_dir': '../models/testsociedad'}
# INFO:tensorflow:Using config: {'_task_type': None, '_task_id': 0, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7fc6963ac160>, '_master': '', '_num_ps_replicas': 0, '_num_worker_replicas': 0, '_environment': 'local', '_is_chief': True, '_evaluation_master': '', '_train_distribute': None, '_tf_config': gpu_options {
#   per_process_gpu_memory_fraction: 1.0
# }
# , '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_secs': None, '_log_step_count_steps': 100, '_session_config': None, '_save_checkpoints_steps': 500, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_model_dir': '../models/testpais'}
# INFO:tensorflow:Using config: {'_task_type': None, '_task_id': 0, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7fc6963ac748>, '_master': '', '_num_ps_replicas': 0, '_num_worker_replicas': 0, '_environment': 'local', '_is_chief': True, '_evaluation_master': '', '_train_distribute': None, '_tf_config': gpu_options {
#   per_process_gpu_memory_fraction: 1.0
# }
# , '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_secs': None, '_log_step_count_steps': 100, '_session_config': None, '_save_checkpoints_steps': 500, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_model_dir': '../models/testtecnologia'}

# %% [markdown]
# # Training

# %%
# Out:
# ###################### tecnologia ######################

# %%
#validation_monitor = {}

print("start")
for key in labels:
    
    validation_monitor = tf.contrib.learn.monitors.ValidationMonitor(
        #input_fn= get_train_inputs(),
        input_fn= get_test_inputs(key),    
        every_n_steps=500,
        #early_stopping_metric="accuracy",#loss
        early_stopping_metric="loss",
        early_stopping_metric_minimize=True,
        early_stopping_rounds=2000)

    start = time.time()
    

    classifier[key].fit(input_fn=get_train_inputs(key), monitors=[validation_monitor], steps=epochs, max_steps=None)
    print("###################### "+key+" ######################")
    
end = time.time()
#print(key)
print("Training time :" + str(end - start) )
# Out:
# start
# WARNING:tensorflow:From /home/pedro/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:279: BaseMonitor.__init__ (from tensorflow.contrib.learn.python.learn.monitors) is deprecated and will be removed after 2016-12-05.
# Instructions for updating:
# Monitors are deprecated. Please use tf.train.SessionRunHook.
# WARNING:tensorflow:From /home/pedro/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:678: ModelFnOps.__new__ (from tensorflow.contrib.learn.python.learn.estimators.model_fn) is deprecated and will be removed in a future version.
# Instructions for updating:
# When switching to tf.estimator.Estimator, use tf.estimator.EstimatorSpec. You can use the `estimator_spec` method to create an equivalent one.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../models/testcultura/model.ckpt-5501
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 5502 into ../models/testcultura/model.ckpt.
# INFO:tensorflow:Starting evaluation at 2018-10-03-14:10:38
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../models/testcultura/model.ckpt-5502
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-10-03-14:10:38
# INFO:tensorflow:Saving dict for global step 5502: accuracy = 0.24948512, global_step = 5502, loss = 5.5376205
# INFO:tensorflow:Validation (step 5502): loss = 5.5376205, accuracy = 0.24948512, global_step = 5502
# INFO:tensorflow:loss = 5.841344, step = 5501
# INFO:tensorflow:global_step/sec: 46.3568
# INFO:tensorflow:loss = 0.7276571, step = 5601 (1.536 sec)
# INFO:tensorflow:global_step/sec: 67.2947
# INFO:tensorflow:loss = 0.56468964, step = 5701 (1.485 sec)
# INFO:tensorflow:global_step/sec: 69.8889
# INFO:tensorflow:loss = 0.4206558, step = 5801 (1.431 sec)
# INFO:tensorflow:global_step/sec: 68.1856
# INFO:tensorflow:loss = 0.3510207, step = 5901 (1.467 sec)
# INFO:tensorflow:Saving checkpoints for 6002 into ../models/testcultura/model.ckpt.
# INFO:tensorflow:global_step/sec: 66.5613
# INFO:tensorflow:loss = 0.278321, step = 6001 (1.502 sec)
# INFO:tensorflow:Starting evaluation at 2018-10-03-14:10:46
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../models/testcultura/model.ckpt-6002
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-10-03-14:10:46
# INFO:tensorflow:Saving dict for global step 6002: accuracy = 0.9120809, global_step = 6002, loss = 0.3103679
# INFO:tensorflow:Validation (step 6002): loss = 0.3103679, accuracy = 0.9120809, global_step = 6002
# INFO:tensorflow:global_step/sec: 52.3829
# INFO:tensorflow:loss = 0.23432283, step = 6101 (1.909 sec)
# INFO:tensorflow:global_step/sec: 70.4311
# INFO:tensorflow:loss = 0.23779094, step = 6201 (1.421 sec)
# INFO:tensorflow:global_step/sec: 67.7242
# INFO:tensorflow:loss = 0.18696743, step = 6301 (1.477 sec)
# INFO:tensorflow:global_step/sec: 69.0303
# INFO:tensorflow:loss = 0.1693434, step = 6401 (1.447 sec)
# INFO:tensorflow:Saving checkpoints for 6502 into ../models/testcultura/model.ckpt.
# INFO:tensorflow:global_step/sec: 67.0731
# INFO:tensorflow:loss = 0.13821083, step = 6501 (1.493 sec)
# INFO:tensorflow:Starting evaluation at 2018-10-03-14:10:53
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../models/testcultura/model.ckpt-6502
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-10
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-10-03-14:39:19
# INFO:tensorflow:Saving dict for global step 27001: accuracy = 0.93132555, global_step = 27001, loss = 0.25082076
# INFO:tensorflow:Validation (step 27001): loss = 0.25082076, accuracy = 0.93132555, global_step = 27001
# INFO:tensorflow:global_step/sec: 51.7041
# INFO:tensorflow:loss = 0.051135823, step = 27100 (1.936 sec)
# INFO:tensorflow:global_step/sec: 71.4427
# INFO:tensorflow:loss = 0.049768105, step = 27200 (1.399 sec)
# INFO:tensorflow:global_step/sec: 71.6341
# INFO:tensorflow:loss = 0.05280399, step = 27300 (1.396 sec)
# INFO:tensorflow:global_step/sec: 70.7723
# INFO:tensorflow:loss = 0.04898831, step = 27400 (1.414 sec)
# INFO:tensorflow:Saving checkpoints for 27501 into ../models/testtecnologia/model.ckpt.
# INFO:tensorflow:global_step/sec: 68.1298
# INFO:tensorflow:loss = 0.044456467, step = 27500 (1.467 sec)
# INFO:tensorflow:Starting evaluation at 2018-10-03-14:39:26
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../models/testtecnologia/model.ckpt-27501
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-10-03-14:39:26
# INFO:tensorflow:Saving dict for global step 27501: accuracy = 0.93170923, global_step = 27501, loss = 0.2505142
# INFO:tensorflow:Validation (step 27501): loss = 0.2505142, accuracy = 0.93170923, global_step = 27501
# INFO:tensorflow:global_step/sec: 48.1935
# INFO:tensorflow:loss = 0.041283987, step = 27600 (2.074 sec)
# INFO:tensorflow:global_step/sec: 72.0427
# INFO:tensorflow:loss = 0.04484417, step = 27700 (1.390 sec)
# INFO:tensorflow:global_step/sec: 73.0231
# INFO:tensorflow:loss = 0.04147544, step = 27800 (1.368 sec)
# INFO:tensorflow:global_step/sec: 71.4181
# INFO:tensorflow:loss = 0.04194922, step = 27900 (1.400 sec)
# INFO:tensorflow:Saving checkpoints for 28000 into ../models/testtecnologia/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.044891723.
# ###################### tecnologia ######################
# Training time :217.0313880443573

# %% [markdown]
# # Evaluation performance

# %%
pred_test = {}
y_test_hat = {}
y_test_hat = {}
acc = {}

for key in labels:

    def input_fn_evaluate():
        dataset = {'x': tf.constant(X_test[key].todense())}    
        return dataset

    pred_test[key] = classifier[key].predict_classes(input_fn=input_fn_evaluate)
    y_test_hat[key] = np.asarray([x.decode('UTF-8') for x in list(pred_test[key])])
    y_test_hat[key] = y_test_hat[key].astype(str)
    acc[key] = accuracy_score(y_true=y_test[key], y_pred=y_test_hat[key])
# Out:
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../models/testcultura/model.ckpt-12003
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../models/testmundo/model.ckpt-28000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../models/testeconomia/model.ckpt-28000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../models/testdeportes/model.ckpt-28000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../models/testentretencion/model.ckpt-26001
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../models/testsociedad/model.ckpt-28000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../models/testpais/model.ckpt-28000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../models/testtecnologia/model.ckpt-28000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.

# %%
for key in labels:
    display(Markdown('## ' + key))
    display(Markdown('## Accuracy in test: {} '.format(acc[key]*100)))    
    skplt.metrics.plot_confusion_matrix(y_test[key], y_test_hat[key],normalize=True,figsize=(20,20))
    plt.xticks(rotation=45)
    plt.show()

    #print('Accuracy in test: {}'.format(acc))
# Out:
# ## cultura
# ## Accuracy in test: 97.2107048624199
# ## mundo
# ## Accuracy in test: 79.5242656449553
# ## economia
# ## Accuracy in test: 95.1086956521739
# ## deportes
# ## Accuracy in test: 75.3868624664456
# ## entretencion
# ## Accuracy in test: 82.20846303834706
# ## sociedad
# ## Accuracy in test: 90.5962762196559
# ## pais
# ## Accuracy in test: 64.96239182595099
# ## tecnologia
# ## Accuracy in test: 94.72094361334868
